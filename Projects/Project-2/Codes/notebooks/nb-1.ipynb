# %% [markdown]
# # NB-1

# %%
import os
import sys

basepath = os.path.abspath(os.path.join(".."))
if not basepath in sys.path:
    sys.path.append(basepath)

# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import numpy as np
from geopy.distance import great_circle
import pandas as pd

# %%
from utils.dataset import DatasetLoader, DatasetLoaderXL

# %%
dsxl = DatasetLoaderXL(dataset_dir="../dataset")
dsxl.load_all_datasets()

# %%
data = dsxl.get_data("Ascot-Vale")

# %%
df = pd.DataFrame(data, columns=['Category', 'Subcategory', 'Value', 'Extra1', 'Extra2'])
df['Category'] = df['Category'].ffill()
df = df.drop(columns=['Extra1', 'Extra2'])
organized_df = df.pivot(index='Subcategory', columns='Category', values='Value')
organized_df.reset_index(inplace=True)

# %%
organized_df
# Out:
# Category                                      Subcategory 2007 population  \
# 0                            % change, 2007-2012, age 0-4             NaN
# 1                          % change, 2007-2012, age 10-14             NaN
# 2                          % change, 2007-2012, age 15-19             NaN
# 3                          % change, 2007-2012, age 20-24             NaN
# 4                          % change, 2007-2012, age 25-44             NaN
# ..                                                    ...             ...
# 221                     Unpaid carer of children, persons             NaN
# 222             Unpaid carer to person with disability, %             NaN
# 223       Unpaid carer to person with disability, persons             NaN
# 224                                         Volunteers, %             NaN
# 225                                   Volunteers, persons             NaN
#
# Category 2007-2012 population change 2012 population Community Diversity  \
# ...

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.metrics.pairwise import euclidean_distances

# Assuming 'organized_df' contains demographic features for different subcategories
# Standardize the demographic features
scaler = StandardScaler()
demographic_features = organized_df.drop(columns=['Subcategory']).values
scaled_features = scaler.fit_transform(demographic_features)

# Calculate the Euclidean distance matrix
distance_matrix = euclidean_distances(scaled_features)

# Convert the distance matrix to a DataFrame for better readability
similarity_df = pd.DataFrame(distance_matrix, index=organized_df['Subcategory'], columns=organized_df['Subcategory'])

similarity_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 8
#       6 scaler = StandardScaler()
#       7 demographic_features = organized_df.drop(columns=['Subcategory']).values
# ----> 8 scaled_features = scaler.fit_transform(demographic_features)
#      10 # Calculate the Euclidean distance matrix
#      11 distance_matrix = euclidean_distances(scaled_features)
#
# File ~/Applications/miniconda3/lib/python3.9/site-packages/sklearn/utils/_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return (
# ...
